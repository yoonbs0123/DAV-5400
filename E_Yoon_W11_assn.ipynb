# %%
import requests
import json
import pandas as pd

# %%
# get new york times api
def get_url(q, begin_date, end_date):
    url = ("https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=o1FRKcoJq9zq0SG1ilG6TnyWAuxT0G83")
    return url

# %%
# only get the data from the date Dec. 1st, 2018 to Jan. 1st, 2019
r = requests.get(get_url('data',20181201,20190101))

# %%
# display in json format
df = r.json()

# %%
df
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'web_url': 'https://query.nytimes.com/gst/abstract.html?res=9A00E2DE123AE63ABC4F52DFB366838C679EDE',
#     'snippet': 'WASHINGTON, May 16-- The Administration proposed to Congress today legislation intended to provide American Indians with better economic and social tools, including a $500million loan guaranty and insurance fund.',
#     'lead_paragraph': 'WASHINGTON, May 16-- The Administration proposed to Congress today legislation intended to provide American Indians with better economic and social tools, including a $500million loan guaranty and insurance fund.',
#     'print_page': '30',
#     'blog': {},
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'PRESIDENT URGES BROAD TRIBAL AID; Bill Proposes $500-Million Loan Fund for Indians',
#      'kicker': None,
#      'content_kicker': None,
# ...

# %%
#get data starting web_url
df1 = df['response']['docs']

# %%
# display in pandas dataframe with the columns I'm interested only, which are four columns below
ny = pd.DataFrame(df1, columns=['headline', 'word_count', 'type_of_material', '_id'])
ny
# Out:
#                                             headline  word_count  \
# 0  {'main': 'PRESIDENT URGES BROAD TRIBAL AID; Bi...         423
# 1  {'main': 'Personalities: One-Two Punch in Tele...        1172
# 2  {'main': 'ZANUCK DISCUSSES FILMS WITH YOUTH; P...         662
# 3  {'main': 'Federal Reserve Unveils More Data', ...         610
# 4  {'main': 'Letters to the Editor of The Times; ...        2271
# 5  {'main': 'Wiretaps Are Played at the Trial of ...        1003
# 6  {'main': 'Odyssey of a Man-- And a Movement; O...        3809
# 7  {'main': 'Art Notes; Hot Off The Drawing Board...        1428
# 8  {'main': 'Letters to the Editor of The Times; ...        1032
# 9  {'main': 'Aspirations in Alabama; Birmingham B...         865
#
#   type_of_material                       _id
# 0          Article  4fc4631045c1498b0d99154b
# 1          Article  4fc4631045c1498b0d99154c
# 2          Article  4fc4631045c1498b0d991551
# 3          Article  4fc4631045c1498b0d991554
# ...

# %% [markdown]
# I signed up New York Times API (https://developer.nytimes.com) to get an API key. Once I get an API key, I bring it to python, and read JSON data accessible via the API, and then transformed that data into a Pandas data frame. The only data I was interested in were these four things: headline, word_count, type_of_material, id. Therefore, I set columns for each then transformed those data into a Pandas data frame.
